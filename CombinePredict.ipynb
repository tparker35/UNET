# %%
from model import *
from data import *
# %run testUnet.ipynb

# %%
modelR = unet()
modelR.load_weights("/data/droppy/unet_membrane4.hdf5")
modelB = unet()
modelB.load_weights("/data/droppy/Humphries_Bragg_Weights.hdf5")

# %%
path = '/data/droppy/Images/Bldg/PAN-PNG/'
pic = 'PAN_AOI_5_Khartoum_img1001.png'

PANImg = Image.open(path+pic)
PANImg
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=650x650 at 0x7FF718312710>

# %%
maskImgR = getMaskR(path+pic)
maskImgR

# %%
compR = displayPrediction(maskImgR,path+pic)
compR
# Out:
# <PIL.Image.Image image mode=RGBA size=650x650 at 0x7FF71836DB90>

# %%
maskImgB = getMaskB(path+pic)
maskImgB
# Out:
# <PIL.Image.Image image mode=RGBA size=256x256 at 0x7FF71835D750>

# %%
compB = displayPrediction(maskImgB,path+pic)
compB
# Out:
# <PIL.Image.Image image mode=RGBA size=650x650 at 0x7FF718312850>

# %%
displayBoth(maskImgR,maskImgB,path+pic)
# Out:
# <PIL.Image.Image image mode=RGBA size=650x650 at 0x7FF71834B110>
