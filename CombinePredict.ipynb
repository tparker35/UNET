# %%
from model import *
from data import *
# %run testUnet.ipynb

# %%
modelR = unet()
modelR.load_weights("/data/droppy/unet_membrane4.hdf5")
modelB = unet()
modelB.load_weights("/data/droppy/Humphries_Bragg_Weights.hdf5")

# %%
path = '/data/droppy/Images/Bldg/PAN-PNG/'
pic = 'PAN_AOI_2_Vegas_img1016.png'

PANImg = Image.open(path+pic)
PANImg
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=650x650 at 0x7FF678070190>

# %%
maskImgR = getMaskR(path+pic)
maskImgR
# Out:
# <PIL.Image.Image image mode=RGBA size=256x256 at 0x7FF67806EB50>

# %%
compR = displayPrediction(maskImgR,path+pic)
compR
# Out:
# <PIL.Image.Image image mode=RGBA size=650x650 at 0x7FF718312110>

# %%
maskImgB = getMaskB(path+pic)
maskImgB
# Out:
# <PIL.Image.Image image mode=RGBA size=256x256 at 0x7FF718312690>

# %%
compB = displayPrediction(maskImgB,path+pic)
compB
# Out:
# <PIL.Image.Image image mode=RGBA size=650x650 at 0x7FF67806E090>

# %%
displayBoth(maskImgR,maskImgB,path+pic)
# Out:
# <PIL.Image.Image image mode=RGBA size=650x650 at 0x7FF67806B6D0>

# %%
pic1 = 'PAN_AOI_2_Vegas_img1000.png'
maskImgR1 = getMaskR(path+pic1)
maskImgB1 = getMaskB(path+pic1)
displayBoth(maskImgR1, maskImgB1,path+pic1)
# Out:
# <PIL.Image.Image image mode=RGBA size=650x650 at 0x7FF678074150>
